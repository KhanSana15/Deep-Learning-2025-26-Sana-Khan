# %% [markdown]
# # ***DATASETS UPLOAD METHODS***

# %% [markdown]
# #**METHOD 1**

# %%
import pandas as pd
path = "/content/sample_data/mnist_train_small.csv"

df1 = pd.read_csv(path)

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
df1.head()

# %% [markdown]
# # **METHOD 2**

# %%
import kagglehub

path = kagglehub.dataset_download("himanshunakrani/iris-dataset")

print("Path to dataset files:", path)

# %%
import os
print(os.listdir(path))

# %%
full_path = path + '/creditcard.csv'

df2 = pd.read_csv(full_path)

df2.head()

# %% [markdown]
# # **METHOD 3**

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import pandas as pd
file_path='/content/drive/MyDrive/mnist_train_small.csv'
df3=pd.read_csv(file_path)

# %%
df3.head()

# %% [markdown]
# # **METHOD 4**

# %%
import kagglehub
path = kagglehub.dataset_download("mlg-ulb/creditcardfraud")

# %%
import os
print(os.listdir(path))

# %%
full_path = path + '/creditcard.csv'

df4 = pd.read_csv(full_path)

df4.head()
